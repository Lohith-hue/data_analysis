# %%
import geopandas as gpd
import pandas as pd

# %%
DNCR_I_LOC = gpd.read_file('/home/lohitd@nextbillion.ai/Downloads/DNCR_I_LOC.geojson')
DNCR_I_LOC_1_Clip = gpd.read_file('/home/lohitd@nextbillion.ai/Downloads/DNCR_I_LOC_1_Clip (2).geojson')
# Out:
# -------------------------------------------------------------------------
# CPLE_OpenFailedError                    Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: /home/lohitd@nextbillion.ai/Downloads/DNCR_I_LOC.geojson: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                             Traceback (most recent call last)
# <ipython-input-4-9b5b3cb8cf6f> in <module>
# ----> 1 DNCR_I_LOC = gpd.read_file('/home/lohitd@nextbillion.ai/Downloads/DNCR_I_LOC.geojson')
#       2 DNCR_I_LOC_1_Clip = gpd.read_file('/home/lohitd@nextbillion.ai/Downloads/DNCR_I_LOC_1_Clip (2).geojson')
#
# ~/anaconda3/lib/python3.8/site-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, rows, **kwargs)
#     199
#     200     with fiona_env():
# --> 201         with reader(path_or_bytes, **kwargs) as features:
# ...

# %%
DNCR_I_LOC.head(3)
# Out:
#               I_LOC  type     I_CITY        I_STATE landuse  name alt. name  \
# 0  Mahindra Enclave  None  Ghaziabad  Uttar Pradesh    None  None      None
# 1         Naya Ganj  None  Ghaziabad  Uttar Pradesh    None  None      None
# 2           Gharoli  None      Delhi          Delhi    None  None      None
#
#   Postal_cod STATE  CITY S_S_LOCA S_LOCALITY postal_c_1 I_state_1 I_city_1  \
# 0       None  None  None     None       None       None      None     None
# 1       None  None  None     None       None       None      None     None
# 2       None  None  None     None       None       None      None     None
#
#   I_loc_1 Alt. nam_1 LOCALITY test_1 Sheet1_Field2  \
# 0    None       None     None                  yes
# 1    None       None     None                  yes
# 2    None       None     None                  yes
#
#                                             geometry
# 0  MULTIPOLYGON (((77.46364 28.67109, 77.46664 28...
# ...

# %%
DNCR_I_LOC_1_Clip.head(3)
# Out:
#               I_LOC  type     I_CITY        I_STATE landuse  name alt. name  \
# 0  Mahindra Enclave  None  Ghaziabad  Uttar Pradesh    None  None      None
# 1         Naya Ganj  None  Ghaziabad  Uttar Pradesh    None  None      None
# 2           Gharoli  None      Delhi          Delhi    None  None      None
#
#   Postal_cod STATE  CITY S_S_LOCA S_LOCALITY postal_c_1 I_state_1 I_city_1  \
# 0       None  None  None     None       None       None      None     None
# 1       None  None  None     None       None       None      None     None
# 2       None  None  None     None       None       None      None     None
#
#   I_loc_1 Alt. nam_1 LOCALITY test_1 She  \
# 0    None       None     None        yes
# 1    None       None     None        yes
# 2    None       None     None        yes
#
#                                             geometry
# 0  MULTIPOLYGON (((77.46364 28.67109, 77.46664 28...
# 1  MULTIPOLYGON (((77.42554 28.66937, 77.43178 28...
# ...

# %%
only_geometry = list(l1_l2['geometry'])
# Out:
# -------------------------------------------------------------------------
# NameError                               Traceback (most recent call last)
# <ipython-input-1-f10068137ac8> in <module>
# ----> 1 only_geometry = list(l1_l2['geometry'])
#
# NameError: name 'l1_l2' is not defined

# %%
out_list = []

for indices, row in DNCR_I_LOC_1_Clip.iterrows():
    num = 0
    
    for each in only_geometry:
        if row['geometry'].contains(each):
            num+= 1     
        else:
            num+= 0  
            
    out_list.append(num)
# Out:
# -------------------------------------------------------------------------
# NameError                               Traceback (most recent call last)
# <ipython-input-2-6adcd3a43a6e> in <module>
#       1 out_list = []
#       2
# ----> 3 for indices, row in DNCR_I_LOC_1_Clip.iterrows():
#       4     num = 0
#       5
#
# NameError: name 'DNCR_I_LOC_1_Clip' is not defined

# %%
DNCR_I_LOC_1_Clip['geometry_type'] = out_list

# %%
DNCR_I_LOC_1_Clip.to_file('/home/lohitd@nextbillion.ai/Downloads/DNCR_I_LOC_1_Clip_geometry_type.geojson', driver='GeoJSON')

# %%
l3 = DNCR_I_LOC_1_Clip[DNCR_I_LOC_1_Clip['geometry_type'] <= 1]

# %%
l1_l2 = DNCR_I_LOC_1_Clip[DNCR_I_LOC_1_Clip['geometry_type'] > 1]

# %%
len(only_geometry)
# Out:
# 156

# %%
len(out_list)
# Out:
# 156

# %%
l1_l2['geometry_type'] = out_list
# Out:
# /home/lohitd@nextbillion.ai/anaconda3/lib/python3.8/site-packages/geopandas/geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %%
l2 = l1_l2[l1_l2['geometry_type'] <= 1]

# %%
l1 = l1_l2[l1_l2['geometry_type'] > 1]

# %%
l2
# Out:
#                  I_LOC  type         I_CITY        I_STATE landuse  name  \
# 1            Naya Ganj  None      Ghaziabad  Uttar Pradesh    None  None
# 8           Kanjhawala  None          Delhi          Delhi    None  None
# 48     Surajpur Site 4  None  Greater Noida  Uttar Pradesh    None  None
# 59        Palam Colony  None          Delhi          Delhi    None  None
# 73           Shakarpur  None          Delhi          Delhi    None  None
# ...                ...   ...            ...            ...     ...   ...
# 2368   West End Colony  None          Delhi          Delhi    None  None
# 2380  North East Delhi  None          Delhi          Delhi    None  None
# 2388   Avantika Colony  None      Ghaziabad  Uttar Pradesh    None  None
# 2389         Masudabad  None          Delhi          Delhi    None  None
# 2411       Ballabhgarh  None      Faridabad        Haryana    None  None
#
#      alt. name Postal_cod STATE  CITY  ... S_LOCALITY postal_c_1 I_state_1  \
# ...

# %%
l3
# Out:
#                      I_LOC  type     I_CITY        I_STATE landuse  name  \
# 0         Mahindra Enclave  None  Ghaziabad  Uttar Pradesh    None  None
# 2                  Gharoli  None      Delhi          Delhi    None  None
# 3     Indra Complex Colony  None  Faridabad        Haryana    None  None
# 4                Jai Vihar  None      Delhi          Delhi    None  None
# 5              Hoshiyarpur  None      Noida  Uttar Pradesh    None  None
# ...                    ...   ...        ...            ...     ...   ...
# 2408  Govindpuri Extension  None      Delhi          Delhi    None  None
# 2409          Rajiv Colony  None  Ghaziabad  Uttar Pradesh    None  None
# 2410   Durgapuri Extension  None      Delhi          Delhi    None  None
# 2412      Samaspur Village  None      Delhi          Delhi    None  None
# 2413    Karawal Nagar West  None      Delhi          Delhi    None  None
#
#      alt. name Postal_cod STATE  CITY  ... S_LOCALITY postal_c_1 I_state_1  \
# ...

# %%
len(out_list)
# Out:
# 2406

# %%
l1_l2.drop(columns = 'geometry_type', inplace = True)
# Out:
# /home/lohitd@nextbillion.ai/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
l1_l2['geometry_type'] = out_list
# Out:
# /home/lohitd@nextbillion.ai/anaconda3/lib/python3.8/site-packages/geopandas/geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %%
l1_l2
# Out:
#                      I_LOC  type     I_CITY        I_STATE landuse  name  \
# 0         Mahindra Enclave  None  Ghaziabad  Uttar Pradesh    None  None
# 1                Naya Ganj  None  Ghaziabad  Uttar Pradesh    None  None
# 2                  Gharoli  None      Delhi          Delhi    None  None
# 3     Indra Complex Colony  None  Faridabad        Haryana    None  None
# 4                Jai Vihar  None      Delhi          Delhi    None  None
# ...                    ...   ...        ...            ...     ...   ...
# 2409          Rajiv Colony  None  Ghaziabad  Uttar Pradesh    None  None
# 2410   Durgapuri Extension  None      Delhi          Delhi    None  None
# 2411           Ballabhgarh  None  Faridabad        Haryana    None  None
# 2412      Samaspur Village  None      Delhi          Delhi    None  None
# 2413    Karawal Nagar West  None      Delhi          Delhi    None  None
#
#      alt. name Postal_cod STATE  CITY  ... S_LOCALITY postal_c_1 I_state_1  \
# ...

# %%
l1.to_file('/home/lohitd@nextbillion.ai/Downloads/DNCR_I_LOC_1_Clip_l1.geojson', driver = 'GeoJSON')
l2.to_file('/home/lohitd@nextbillion.ai/Downloads/DNCR_I_LOC_1_Clip_l2.geojson', driver = 'GeoJSON')
l3.to_file('/home/lohitd@nextbillion.ai/Downloads/DNCR_I_LOC_1_Clip_l3.geojson', driver = 'GeoJSON')

# %%
DNCR_I_LOC_1_Clip['geometry'][0].contains(only_geometry[0])
# Out:
# True

# %%
len(only_geometry)
# Out:
# 2414
